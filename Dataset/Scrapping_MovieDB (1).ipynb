# %%
pip install tmdbv3api

# %%
from tmdbv3api import TMDb                # untuk mengakses API tmdb
from tmdbv3api import Movie               # untuk mengakses data film tmdb
import pandas as pd                       # untuk mengolah data tabular
from datetime import datetime

# %% [markdown]
# #200 page

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb, Movie
import pandas as pd
from time import sleep

# --- Setup TMDb ---
tmdb = TMDb()
tmdb.api_key = '3e730b30512651f4b46a94a014fbfd06'
tmdb.language = 'en'

movie = Movie()

# --- Ambil daftar film populer (halaman 1) ---
popular_movies = movie.popular(page=1)

# --- Ambil detail untuk masing-masing film ---
movie_data = []

for m in popular_movies:
    details = movie.details(m.id)

    genres = ", ".join([g['name'] for g in details.genres]) if details.genres else None

    movie_data.append({
        'movie_id': m.id,
        'title': m.title,
        'original_title': details.original_title,
        'overview': m.overview,
        'release_date': m.release_date,
        'vote_average (%)': round(m.vote_average * 10, 2),
        'vote_count': m.vote_count,
        'popularity': m.popularity,
        'runtime (min)': details.runtime,
        'status': details.status,
        'tagline': details.tagline,
        'genres': genres,
        'budget': details.budget,
        'revenue': details.revenue,
        'original_language': details.original_language
    })

    sleep(0.3)  # Tambahkan jeda agar tidak overload API

# --- Simpan ke DataFrame ---
df = pd.DataFrame(movie_data)
df

# (Opsional) Simpan ke CSV
# df.to_csv('detailed_popular_movies.csv', index=False)
# Out:
#     movie_id                             title  \
# 0    1233069                     Exterritorial
# 1    1197306                     A Working Man
# 2     668489                             Havoc
# 3    1471014               Van Gogh by Vincent
# 4     986056                     Thunderbolts*
# 5     950387                 A Minecraft Movie
# 6    1225915     Jewel Thief: The Heist Begins
# 7     822119  Captain America: Brave New World
# 8     324544                 In the Lost Lands
# 9    1153714                Death of a Unicorn
# 10   1414048                  Day of Reckoning
# 11   1356236                   Saint Catherine
# 12   1180906                       Desert Dawn
# 13   1233413                           Sinners
# 14    974573              Another Simple Favor
# 15   1124620                        The Monkey
# 16   1276073            Bullet Train Explosion
# 17   1249213                              Drop
# 18       348                             Alien
# ...

# %%
from tmdbv3api import TMDb, Movie
import pandas as pd
from time import sleep

# --- Setup TMDb ---
tmdb = TMDb()
tmdb.api_key = '3e730b30512651f4b46a94a014fbfd06'
tmdb.language = 'en'

movie = Movie()

# --- Ambil 200 halaman film populer ---
movie_data = []

for page in range(1, 201):  # Ambil halaman 1 sampai 200 (sekitar 4000 film)
    print(f"Processing page {page}...")
    try:
        popular_movies = movie.popular(page=page)

        for m in popular_movies:
            try:
                details = movie.details(m.id)
                genres = ", ".join([g['name'] for g in details.genres]) if details.genres else None

                movie_data.append({
                    'movie_id': m.id,
                    'title': m.title,
                    'original_title': details.original_title,
                    'overview': m.overview,
                    'release_date': m.release_date,
                    'vote_average (%)': round(m.vote_average * 10, 2),
                    'vote_count': m.vote_count,
                    'popularity': m.popularity,
                    'runtime (min)': details.runtime,
                    'status': details.status,
                    'tagline': details.tagline,
                    'genres': genres,
                    'budget': details.budget,
                    'revenue': details.revenue,
                    'original_language': details.original_language
                })

                sleep(0.5)  # Hindari rate limit
            except Exception as e:
                print(f"Failed to get details for movie ID {m.id}: {e}")
    except Exception as e:
        print(f"Failed to get page {page}: {e}")

# --- Simpan ke DataFrame ---
df = pd.DataFrame(movie_data)
df
# --- Simpan ke CSV ---
df.to_csv('popular_movies_200_pages.csv', index=False)
# Out:
# Processing page 1...
# Processing page 2...
# Processing page 3...
# Processing page 4...
# Processing page 5...
# Processing page 6...
# Processing page 7...
# Processing page 8...
# Processing page 9...
# Processing page 10...
# Processing page 11...
# Processing page 12...
# Processing page 13...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/S2 - SEMESTER 2/Manajemen Data Statistika/Praktikum - UAS/popular_movies_200_pages.csv')

# %%
df
# Out:
#       movie_id                                              title  \
# 0      1197306                                      A Working Man
# 1       668489                                              Havoc
# 2       950387                                  A Minecraft Movie
# 3      1471014                                Van Gogh by Vincent
# 4      1276073                             Bullet Train Explosion
# ...        ...                                                ...
# 3995    128883  Crayon Shin-chan: The Legend Called Dance! Amigo!
# 3996      3784                                 Frankie and Johnny
# 3997       768                                          From Hell
# 3998    405774                                           Bird Box
# 3999    465595                                          Sweet Sex
#
#                 original_title  \
# 0                A Working Man
# 1                        Havoc
# 2            A Minecraft Movie
# 3          Van Gogh by Vincent
# ...

# %%
# Convert 'release_date' to datetime objects if it's not already
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# Extract year and month and format them as 'YYYY-MM'
df['release_year_month'] = df['release_date'].dt.strftime('%Y-%m')

df['release_year'] = pd.to_datetime(df['release_date'], errors='coerce').dt.year
df['release_year'] = df['release_year'].astype('Int64') # Use nullable integer type

# Example to display the updated DataFrame
df[['release_date', 'release_year_month', 'release_year']]
# Out:
#      release_date release_year_month  release_year
# 0      2025-03-26            2025-03          2025
# 1      2025-04-24            2025-04          2025
# 2      2025-03-31            2025-03          2025
# 3      2025-03-26            2025-03          2025
# 4      2025-04-23            2025-04          2025
# ...           ...                ...           ...
# 3995   2006-04-15            2006-04          2006
# 3996   1991-10-11            1991-10          1991
# 3997   2001-02-08            2001-02          2001
# 3998   2018-12-13            2018-12          2018
# 3999   2017-07-06            2017-07          2017
#
# [4000 rows x 3 columns]

# %%
df
# Out:
#       movie_id                                              title  \
# 0      1197306                                      A Working Man
# 1       668489                                              Havoc
# 2       950387                                  A Minecraft Movie
# 3      1471014                                Van Gogh by Vincent
# 4      1276073                             Bullet Train Explosion
# ...        ...                                                ...
# 3995    128883  Crayon Shin-chan: The Legend Called Dance! Amigo!
# 3996      3784                                 Frankie and Johnny
# 3997       768                                          From Hell
# 3998    405774                                           Bird Box
# 3999    465595                                          Sweet Sex
#
#                 original_title  \
# 0                A Working Man
# 1                        Havoc
# 2            A Minecraft Movie
# 3          Van Gogh by Vincent
# ...

# %%
import json, os

# Convert the DataFrame to JSON format
json_popular_movies_200 = df.to_json(orient='records')

# Specify the folder path
folder_path = 'json_data'

# Create the folder if it doesn't exist
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Specify the file path within the folder
file_path = os.path.join(folder_path, 'popular_movies_new.json')

# Save the JSON data to the file
with open(file_path, 'w') as f:
    json.dump(json.loads(json_popular_movies_200), f, indent=4)

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
print(os.listdir(f"{shared_root}/Praktikum - UAS"))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-97086ed68a73> in <cell line: 0>()
#       2 import os
#       3 drive.mount('/content/drive')
# ----> 4 print(os.listdir(f"{shared_root}/Praktikum - UAS"))
#
# NameError: name 'shared_root' is not defined

# %%
#!pip install pymongo

from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import json

# 1. Setup Koneksi MongoDB
uri = "mongodb+srv://root:1234@mds-db.dtk5gzr.mongodb.net/?retryWrites=true&w=majority&appName=mds-db"
client = MongoClient(uri, server_api=ServerApi('1'))

# 2. Pilih Database & Collection
db = client['mds-db']
collection = db['popular_movies']

# 3. Tes Koneksi
try:
    client.admin.command('ping')
    print("✅ Berhasil terhubung ke MongoDB!")
except Exception as e:
    print("❌ Gagal terhubung:", e)

# 4. Insert Data dari JSON
with open('/content/drive/Shared drives/Praktikum - UAS/popular_movies.json', 'r') as file:
    data = json.load(file)

if isinstance(data, list):
    result = collection.insert_many(data)
    print(f"✅ {len(result.inserted_ids)} data dimasukkan!")
else:
    result = collection.insert_one(data)
    print(f"✅ 1 data dimasukkan (ID: {result.inserted_id})")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
